# %%
# !pip install numpy

# %%
# !pip install pandas

# %%
# !pip install seaborn

# %%
# %matplotlib inline
import matplotlib
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# !pip install matplotlib

# %%
data = pd.read_csv("C:/Users/DELL/Downloads/archive/Cuisine_rating.csv")

# %%
data.head()
# Out:
#    User ID  Area code            Location  Gender   YOB Marital Status  \
# 0        1        153  Upper East Side,NY  Female  2006         Single
# 1        2        123       St. George,NY  Female  1991        Married
# 2        3        122  Upper West Side,NY    Male  1977         Single
# 3        4        153  Upper East Side,NY  Female  1956        Married
# 4        5        129     Central Park,NY    Male  1997         Single
#
#        Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# 0  Professional       3  Japanese     Never     Never            5
# 1       Student       3    Indian     Never  Socially            1
# 2       Student       5   Seafood     Often     Often            5
# 3  Professional       5  Japanese     Never  Socially            3
# 4       Student       4  Filipino  Socially     Never            2
#
#    Service Rating  Overall Rating Often A S
# 0               4             4.5        No
# 1               1             1.0        No
# ...

# %%
data.describe()
# Out:
#           User ID   Area code          YOB      Budget  Food Rating  \
# count  200.000000  200.000000   200.000000  200.000000   200.000000
# mean   100.500000  141.060000  1984.830000    3.815000     3.220000
# std     57.879185   26.130257    16.809339    1.056578     1.411226
# min      1.000000  101.000000  1955.000000    1.000000     1.000000
# 25%     50.750000  123.000000  1971.000000    3.000000     2.000000
# 50%    100.500000  135.000000  1987.000000    4.000000     3.000000
# 75%    150.250000  158.000000  2000.000000    5.000000     5.000000
# max    200.000000  199.000000  2009.000000    5.000000     5.000000
#
#        Service Rating  Overall Rating
# count      200.000000      200.000000
# mean         3.230000        3.225000
# std          1.526022        1.079445
# min          1.000000        1.000000
# 25%          2.000000        2.500000
# 50%          3.000000        3.000000
# 75%          5.000000        4.000000
# max          5.000000        5.000000

# %%
data.nunique()
# Out:
# User ID           200
# Area code          65
# Location           10
# Gender              2
# YOB                46
# Marital Status      3
# Activity            2
# Budget              5
# Cuisines            7
# Alcohol             3
# Smoker              3
# Food Rating         5
# Service Rating      5
# Overall Rating      9
# Often A S           2
# dtype: int64

# %%
Cuisine_rating.nunique()
# Out:
# Location          10
# Gender             2
# YOB               46
# Marital Status     3
# Activity           2
# Budget             5
# Cuisines           7
# Alcohol            3
# Smoker             3
# Food Rating        5
# Service Rating     5
# Overall Rating     9
# Often A S          2
# dtype: int64

# %%
data.isnull().sum()
# Out:
# User ID           0
# Area code         0
# Location          0
# Gender            0
# YOB               0
# Marital Status    0
# Activity          0
# Budget            0
# Cuisines          0
# Alcohol           0
# Smoker            0
# Food Rating       0
# Service Rating    0
# Overall Rating    0
# Often A S         0
# dtype: int64

# %%
Cuisine_rating = data.drop(['Often A S'], axis=1)

# %%
Cuisine_rating.head()
# Out:
#    User ID  Area code            Location  Gender   YOB Marital Status  \
# 0        1        153  Upper East Side,NY  Female  2006         Single
# 1        2        123       St. George,NY  Female  1991        Married
# 2        3        122  Upper West Side,NY    Male  1977         Single
# 3        4        153  Upper East Side,NY  Female  1956        Married
# 4        5        129     Central Park,NY    Male  1997         Single
#
#        Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# 0  Professional       3  Japanese     Never     Never            5
# 1       Student       3    Indian     Never  Socially            1
# 2       Student       5   Seafood     Often     Often            5
# 3  Professional       5  Japanese     Never  Socially            3
# 4       Student       4  Filipino  Socially     Never            2
#
#    Service Rating  Overall Rating
# 0               4             4.5
# 1               1             1.0
# ...

# %%
corelation = Cuisine_rating.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <AxesSubplot:>

# %%
# here we can see without data just random heatmap  
uniform_data = np.random.rand(10, 8)
ax = sns.heatmap(uniform_data)

# %%
Cuisine_rating = data.drop(['User ID','Area code'], axis=1)

# %%
sns.pairplot(Cuisine_rating)

# %%
sns.relplot(x='Food Rating', y='Service Rating', hue='Overall Rating', data=Cuisine_rating )

# %%
sns.distplot(Cuisine_rating['Overall Rating'], bins=10)
# Out:
# C:\Users\DELL\anaconda3\envs\rstudio-\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Overall Rating', ylabel='Density'>

# %%
sns.catplot(x='Food Rating', kind='box', data= Cuisine_rating)

# %%
sns.catplot(x='Service Rating', kind='box', data= Cuisine_rating)

# %%
sns.catplot(x='Overall Rating', kind='box', data= Cuisine_rating)
